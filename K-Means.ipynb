# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# Klasterovanje korišćenjem K srednjih vrednosti

# %%
#centers = [[1, 1], [-1, -1], [1, 0]]
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.6, random_state=50)

points = data[0]

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='viridis')
plt.show()

# %%
# K srednjih 
kmeans = KMeans(n_clusters=5)


kmeans.fit(points)
#print(kmeans.cluster_centers_)

# Novi klasteri za izcrtavanje
y_km = kmeans.fit_predict(points)

# %%
plt.scatter(points[y_km ==0,0], points[y_km == 0,1], c='red')
plt.scatter(points[y_km ==1,0], points[y_km == 1,1], c='black')
plt.scatter(points[y_km ==2,0], points[y_km == 2,1], c='blue')
plt.scatter(points[y_km ==3,0], points[y_km == 3,1], c='cyan')
plt.scatter(points[y_km ==4,0], points[y_km == 4,1], c='green')
plt.show()
